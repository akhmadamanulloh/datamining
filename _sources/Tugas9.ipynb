# %% [markdown]
# # REGRESI LINIER

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([115.27868249])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
import pandas as pd
data = {'X':x,
        'Y':y}
df=pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X          Y
# 0    [-0.8097281947130283] -34.381142
# 1   [-0.42121381613069564]  -9.794028
# 2    [-0.5696905835303608] -17.083098
# 3     [0.2631976199267294]  15.670320
# 4     [1.8267614390431686]  69.092424
# 5    [-1.6069767960175194] -31.740612
# 6     [0.0975616499275806]  18.742134
# 7     [1.0474797062517924]  43.693686
# 8   [-0.24907155284639124]  -6.039854
# 9    [-1.2914923604128048] -58.433830
# 10  [-0.39162761367558296] -16.374867
# 11     [1.467223002801978]  53.144053
# 12   [0.06320668000464269]   4.660788
# 13    [-1.798175500660525] -70.404585
# 14   [0.08363504037571098]  -4.700441
# 15     [0.654785675165826]  24.197953
# 16   [-1.3102164899197568] -64.738427
# 17   [0.08507991764757063]   3.365352
# 18     [1.052775591965074]  42.967114
# 19    [1.0437419948996893]  44.446132

# %%
reg.coef_
# Out:
# array([37.8403674])

# %%
reg.intercept_
# Out:
# 1.757580297520084

# %%
pyplot.scatter(X_test,y_test)
Y_plot=reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test,Y_plot,color='r')
pyplot.show()
