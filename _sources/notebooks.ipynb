# %% [markdown]
# # Tugas 1

# %% [markdown]
# #membuat skewned data

# %% [markdown]
# 1. Membaca data dari url
# 2. Membuat statistik diskriptif dari data (setiap atribut yang bertipe numerik)
# 3. Mendiskripsikan kemiringan/skewned dari data setiap variabel (bertipe numerik)

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/akhmadamanulloh/main/main/data-penindakan-pelanggaran-lalu-lintas-dan-angkutan-jalan-tahun-2021-bulan-januari.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wilayah              6 non-null      object
#  1   bap_tilang           6 non-null      int64
#  2   stop_operasi         6 non-null      int64
#  3   bap_polisi           6 non-null      int64
#  4   stop_operasi_polisi  6 non-null      int64
#  5   penderekan           6 non-null      int64
#  6   ocp_roda_dua         6 non-null      int64
#  7   ocp_roda_empat       6 non-null      int64
#  8   angkut_motor         6 non-null      int64
# dtypes: int64(8), object(1)
# memory usage: 560.0+ bytes

# %%
df
# Out:
#                     wilayah  bap_tilang  stop_operasi  bap_polisi  \
# 0             Bidang Dalops          44           139           0
# 1    Sudinhub Jakarta Pusat          47             2          52
# 2    Sudinhub Jakarta Utara         166            27           0
# 3  Sudinhub Jakarta Selatan          44             1           0
# 4    Sudinhub Jakarta Barat         184            70           0
# 5    Sudinhub Jakarta Timur         191           141           0
#
#    stop_operasi_polisi  penderekan  ocp_roda_dua  ocp_roda_empat  angkut_motor
# 0                    0          73             0               0             0
# 1                    0         184           237              15            97
# 2                    0         174             0               0             0
# 3                    0          61            42              75             0
# 4                    0         202            10               5             0
# ...

# %%
df.describe()
# Out:
#        bap_tilang  stop_operasi  bap_polisi  stop_operasi_polisi  penderekan  \
# count    6.000000      6.000000    6.000000                  6.0    6.000000
# mean   112.666667     63.333333    8.666667                  0.0  138.500000
# std     74.580605     64.450498   21.228911                  0.0   59.433156
# min     44.000000      1.000000    0.000000                  0.0   61.000000
# 25%     44.750000      8.250000    0.000000                  0.0   89.000000
# 50%    106.500000     48.500000    0.000000                  0.0  155.500000
# 75%    179.500000    121.750000    0.000000                  0.0  181.500000
# max    191.000000    141.000000   52.000000                  0.0  202.000000
#
#        ocp_roda_dua  ocp_roda_empat  angkut_motor
# count      6.000000        6.000000      6.000000
# mean      48.166667       15.833333     16.166667
# std       93.928519       29.566310     39.600084
# min        0.000000        0.000000      0.000000
# ...

# %%
import seaborn as sns
sns.distplot(df['stop_operasi'] ,hist=True, kde=True, bins=int(180/5), color='blue', hist_kws= {'edgecolor':'black'}, kde_kws={'linewidth':5})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
